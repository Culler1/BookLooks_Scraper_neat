# %%
# %run scrape_with_PDF.py

# %%
# %run scraper1.py
# Out:
# There are 586 books listed on BookLooks as of 06/07/2023.
# There were 586 files as of 06/06/2023.
# There have been 46 books added since 05/06/2023
# Roughly 46.0% of BookLooks' current titles are rated three or higher.
# Ellen Hopkins is the most frequently mentioned author with 20 titles in this list.

# %%
import PyPDF2
import re

# %%
text1 = []
pdf_file = "BookLooks_reports/Cool for the Summer.pdf"
def extract_text_from_pdf(pdf_file: str)->[str]:
    with open(pdf_file,'rb') as pdf:
        pdf_text = []
        reader = PyPDF2.PdfReader(pdf_file, strict=False)
        content = reader.pages[0].extract_text()
        pdf_text.append(content)
        return pdf_text

        
#         for page in reader.pages:
#             content = page.extract_text()
#             pdf_text.append(content)
#         return pdf_text

if __name__ == '__main__':
    extracted_text = extract_text_from_pdf(pdf_file)
    for text in extracted_text:
        text1.append(text)
        print(text)
# Out:
#
#
#
#
# COOL FOR THE SUMMER
#
# Young Adult   Book Summary:
# A teenage girl is conflicted about her
# sexuality while she has romantic
# relationships with another teenage girl
# and her long -time  boy crush.
#
# Sum mary of Concer ns:
# This book contain s alternate gender
# ideologies; profanity; sexual activities;
# sexual nudity; and alternate sexualities .
# By Dahlia Adler
# ISBN:  978 -1-250 -76582 -6

# %%
re.search('(?<=\n\n\n\n :).*',text)

# %%
pattern = '[A-Z]+[a-z]+$'
re.search(pattern,text)

# %%
te

# %%
pdf_file = "BookLooks_reports/Cool for the Summer.pdf"
reader = PdfReader(filename)
string1=reader.pages[0].extract_text()

# %%
re.match(("?<=test).*",text1[0])

# %%
res = [sub.replace("\n", " ",) for sub in text1]

# %%
res
# Out:
# ['        AN ORDINARY DAY     Juvenile   Book Summary:   Two neighborhood children learn about  life and death through the birth and death  of family members.   Summary of Concerns:   This book contains disc ussions  of death.   By Elana K. Arnold    ISBN:  978 -1-48147262 -3          ']

# %%
pdf = 'BookLooks_reports/BlackLives Matter.pdf'
reader = PyPDF2.PdfReader(pdf,strict=False)
title_page = reader.pages[0]

# %%
pdf_file = "BookLooks_reports/Cool for the Summer.pdf"
reader = PdfReader(filename)
string1=reader.pages[0].extract_text()
page = reader.pages[0]
page.extract_text(0)
parts = []
def visitor_body(text, cm, tm, fontDict,fontSize):
    y = tm[5]
    if y > 50 and y <700:
        parts.append(text)
page.extract_text(visitor_text=visitor_body)
text_body = "".join(parts)
#title_page.extract_text()

# %%
text_body
# Out:
# '\n COOL FOR THE SUMMER  \n \nYoung Adult   Book Summary:  \nA teenage girl is conflicted about her \nsexuality while she has romantic \nrelationships with another teenage girl \nand her long -time  boy crush.  \n \nSum mary of Concer ns: \nThis book contain s alternate gender \nideologies; profanity; sexual activities; \nsexual nudity; and alternate sexualities . \nBy Dahlia Adler   \nISBN:  978 -1-250 -76582 -6 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n'

# %%
page.extract_text()
# Out:
# ' \n \n \n \n101 WAYS TO DANCE  \n \nYoung Adult   Summary of Concerns:  \nThis book contains inexplicit references to \nsexual nudity and sexual activities .   \nBy Kathy Stinson   \nISBN:  978-1-897187 -10-4 \n \n \n \n \n \n \n \n \n \n \n \n978 -1-897187 -10-4 \n1-897187 -10-6 \n978 -0-329 -50477 -9 \n978 -0-329 -62758 -4 \n0-329 -50477 -0 \n0-329 -62758 -9 \n'

# %%
filename = "BookLooks_reports/10000 Dresses.pdf"

# %%
from PyPDF2 import PdfReader
    reader = PdfReader(filename)
    print(f'Number of pages: {len(reader.pages)}')
    print(f'{reader.pages[0].extract_text()}')

# %%
filename = "BookLooks_reports/10000 Dresses.pdf"
reader = PdfReader(filename)
string1=reader.pages[0].extract_text()
page = reader.pages[0]
page.extract_text(0)
# Out:
# ' \n \n \n \nALL THE THING S WE \nDO IN THE DARK  \n \nYoung Adult   Book Summary:  \nA teenage girl  attempts  to have a normal \nlife after having been raped as a  child.  \nSummary of Conc erns:  \nThis book contains mild /infrequent  \nprofanity; sexual activities; alternate \nsexualities; and suicide references . \nBy Saundra Mitchell   \nISBN:  978 -0-06-285259 -5 \n \n \n \n   \n \n \n \n \n'

# %%
reader = PdfReader(filename)
string1=reader.pages[0].extract_text()
page = reader.pages[0]
page.extract_text(0)
# Out:
# " \n \n \n \n10,000 DRESSES  \n \nEasy Reader   Book Summary:  \nA young boy dreams of wearing dresses \nand eventually does despite his family's \nprotestations.  \n \nSummary of Concerns:  \nThis book  contains alternate gender \nideologies.  \nBy Marcus Ewert   \nISBN: 978 -1-58322 -850 -0 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n"

# %%
page.extract_text()
# Out:
# " \n \n \n \n10,000 DRESSES  \n \nEasy Reader   Book Summary:  \nA young boy dreams of wearing dresses \nand eventually does despite his family's \nprotestations.  \n \nSummary of Concerns:  \nThis book  contains alternate gender \nideologies.  \nBy Marcus Ewert   \nISBN: 978 -1-58322 -850 -0 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n"

# %%
import glob
pdfs=[]
titles=[]
path = os.getcwd()+'\\BookLooks_Reports\*.pdf'
for filepath in glob.glob(path):
    titles.append(filepath.split('\\')[-1][:-4].strip())
    pdfs.append(filepath.split('\\')[-1])

# %%
titles
# Out:
# ['10000 Dresses',
#  '101 Ways to Dance',
#  '33 Snowfish',
#  'A Child Called it',
#  'A Costume for Charly',
#  'A Court of Frost and Starlight Slick Sheet',
#  'A Court of Frost and Starlight',
#  'a court of mist and fury slick sheet',
#  'A Court of Mist and Fury',
#  'A Court of Silver Flames Slick Sheet',
#  'A Court of Silver Flames',
#  'A Court of Thorns and Roses slick sheet',
#  'A Court of Thorns and Roses',
#  'A Court of Wings and Ruin slick sheet',
#  'A Court of Wings and Ruin',
#  'A Day No Pigs Would Die',
#  'A is for activist',
#  'A Kingdom of Flesh and Fire Slick Sheet',
#  'A Kingdom of Flesh and Fire',
#  'A Lesson in Vengeance',
#  'A Quick and easy guide to queer and trans identities',
#  'A Quick and easy guide to they them pronouns',
#  'A Sin Such as this slick sheet',
#  'A Sin Such as This',
#  'A stolen life',
#  'Aaron slater illustrator',
#  'Ablaze With Color',
#  'Ace Voices',
#  'Ada twist scientist',
#  'Adjustment Day slick sheet',
#  'Adjustment day',
#  'Advocate for Yourself',
#  'After',
#  'Al Capone does my shirts',
#  'All American Boys',
#  'All Because You Matter',
#  'All Boys Arent Blue Slick Sheet',
#  'All Boys Arent Blue',
#  'All The Bright Places',
#  'All the Things we do in the dark',
#  'All your perfects slick sheet',
#  'All Your Perfects',
#  'Allegedly',
#  'Alma and How she got her name',
#  'Almost perfect',
#  'Alt Ed',
#  'America',
#  'An Abc of equality',
#  'An Ordinary Day',
#  'Anatomy of a Boyfriend slick sheet',
#  'Anatomy of a Boyfriend',
#  'Anatomy of a single Girl',
#  'And tango makes three',
#  'And They Lived slick sheet',
#  'And they lived',
#  'ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON',
#  'Anne Franks Diary graphic novel',
#  'Antiracist baby',
#  'Antonios card',
#  'Are you a boy or are you a girl',
#  'Are You a Butterfly',
#  'Are you an ant',
#  'Are you my Mother A Comic Drama',
#  'as the crow flies',
#  'Ask the Passengers',
#  'Assassination Classroom Volume 11',
#  'Assassination Classroom Volume 2',
#  'Assassination classroom volume 3',
#  'Assassination Classroom volume 4',
#  'Assassination Classroom Volume 5',
#  'Assassination Classroom volume 6',
#  'Assassination Classroom volume 7',
#  'Assassination Classroom',
#  'Attack of the Black Rectangles',
#  'Autoboyography',
#  'Bad Boy',
#  'Ballet KIds',
#  'Ban this book',
#  'Banned Book Club',
#  'Bathe the cat',
#  'Be Amazing',
#  'Be Prepared',
#  'Be who you are',
#  'Bea by the Sea',
#  'Beautiful Bastard',
#  'Beautiful Disaster slick sheet',
#  'Beautiful Disaster',
#  'Beautiful Slick Sheet',
#  'Beautiful',
#  'Beetle and the Hollow Bones',
#  'Before We Disappear',
#  'Being jazz',
#  'Being You a first conversation about gender',
#  'Beloved',
#  'Beyond Magenta',
#  'Big Wig',
#  'BlackLives Matter',
#  'Blankets',
#  'Blazed',
#  'Blended',
#  'Blue is the Warmest Color',
#  'Bodies are cool',
#  'Body Image',
#  'Bone ghost circles',
#  'Born on the Bayou slick sheet',
#  'Born on the Bayou',
#  'Born Ready',
#  'Boy Girl Boy',
#  'Boy Meets Boy',
#  'Boy Toy',
#  'Boys Dance',
#  'Brave New World',
#  'Brazen',
#  'Breathless slicksheet',
#  'Breathless',
#  'Bright Eyes Brown Skin',
#  'Bumped',
#  'bunnyBear',
#  'Burned',
#  'Bye Bye binary',
#  'Call Me By Your Name Slick Sheet',
#  'Call Me By Your Name',
#  'Call Me Max',
#  'Calvin',
#  'Can I Touch Your Hair',
#  'Cant Take That Away',
#  'Catwoman Soulstealer',
#  'Cemetary Boys',
#  'changing You',
#  'Check Please',
#  'Choke slick sheet',
#  'Choke',
#  'Chosen',
#  'Cinderella is Dead',
#  'Clap when you land',
#  'Class Act',
#  'Clockwork princess',
#  'Closer Slick Sheet',
#  'Closer to Nowhere',
#  'Closer',
#  'Collateral Slick Sheet',
#  'Collateral',
#  'Collected Poms 1947 1980',
#  'Concrete Rose',
#  'Confess',
#  'Cool for the Summer',
#  'crank',
#  'Crown of Midnight',
#  'Cuddly Duddley',
#  'Curls',
#  'Cut',
#  'Daddys Roommate',
#  'Damned slick sheet',
#  'Damned',
#  'Damsel Slick Sheet',
#  'Damsel',
#  'Dead End slick sheet',
#  'Dead End',
#  'Deal with it',
#  'Dear martin',
#  'Dear Sweet Pea',
#  'Death Wind',
#  'Deogratias a Tale of Rwand',
#  'dime',
#  'Discrimination in Society Racial Discrimination',
#  'Doing it',
#  'Doll Bones',
#  'Doomed slick sheet',
#  'Doomed',
#  'Dorothy a different kind of friend',
#  'Dragon Masters Heat of the Lava Dragon',
#  'Drama',
#  'Dream Street',
#  'Dreaming in Cuban',
#  'Dreaming Up',
#  'Dress Codes For Small Towns',
#  'Eleanor and Park',
#  'Embrace Series Book 1',
#  'Emergency Contact',
#  'Empire of Storms Slick Sheet',
#  'Empire of Storms',
#  'Eustace and Clyde',
#  'Everything You EVer Wanted to Know About Puberty',
#  'Everywhere Babies',
#  'Exit here slick sheet',
#  'Exit here',
#  'Extremely Loud and INcredibly Close',
#  'Fable',
#  'Fade',
#  'Fallout',
#  'Fangirl',
#  'Far from Fair',
#  'Felix Ever After',
#  'Feral Sins',
#  'Fight Club',
#  'Finding Cinderella',
#  'Finding Perfect',
#  'Flamer',
#  'Flowers in the attic',
#  'Forbidden',
#  'forever for a year slick sheet',
#  'Forever for a Year',
#  'Forever Slick sheet',
#  'Forever',
#  'Foul is Fair',
#  'Fred Gets Dressed',
#  'Friction',
#  'Friday',
#  'From ARchie to Zack',
#  'From Blood and Ash slick sheet',
#  'From Blood and Ash',
#  'Fun Home',
#  'Gabi A Girl in Pieces',
#  'Gender Queer',
#  'George',
#  'Get a life Chloe Brown',
#  'Ghost boys',
#  'Gilded',
#  'Girl in Translation',
#  'Girls Who Code',
#  'Glass',
#  'Go Ask Alice',
#  'Go Back to Sleep',
#  'Goodnight Racism',
#  'Gossip girl Nobody does it better',
#  'Grandpas camper',
#  'Grit',
#  'Grl2Grl',
#  'Grow up and love your body',
#  'Grown',
#  'Guyaholic',
#  'half a chance',
#  'Half of a Yellow Sun',
#  'haunted slick sheet',
#  'Haunted',
#  'Heartstopper volume 1',
#  'Heartstopper Volume 2',
#  'heartstopper Volume 3',
#  'Heartstopper Volume 4',
#  'Heather Has two Mummies',
#  'Heir of Fire',
#  'Heroine',
#  'Hes my mom',
#  'Him slick sheet',
#  'Him',
#  'Home Body',
#  'Homegoing',
#  'Hooked',
#  'Hoonani Hula Warrior',
#  'Hopeless slick sheet',
#  'Hopeless',
#  'House of Earth and Blood slick sheet',
#  'House of Earth and Blood',
#  'House of Sky and Breath slick sheet',
#  'House of Sky and Breath',
#  'how Beautiful the ordinary',
#  'How it all Blew up',
#  'How to be a young antiracist',
#  'How to Read a Book',
#  'How We Can Live',
#  'I Am Jazz',
#  'I am Margaret Moore',
#  'i am not your perfect mexican daughter',
#  'I Dissent',
#  'I is for immigrants',
#  'I Never',
#  'Identical',
#  'Identity a story of transitioning',
#  'If i was your girl',
#  'If Theres no tomorrow',
#  'If You Come Softly',
#  'Ill Give You the Sun',
#  'Im a Girl',
#  'Im a Unicorn',
#  'Im Basically a Unicorn',
#  'im not a girl',
#  'Impulse',
#  'infandous',
#  'Infinity Son',
#  'invisible monsters remix slick sheet',
#  'Invisible Monsters Remix',
#  'Is This Normal More Girls questions answered by the editors of the care and keeping of you',
#  'Is This NOrmal',
#  'It Ends With Us Slick Sheet',
#  'It Ends With Us',
#  'It feels good to be yourself',
#  'It Isnt rude to be nude',
#  'it starts with us slick sheet',
#  'It starts with Us',
#  'Its Not the Stork',
#  'Its Perfectly Normal 5th edition',
#  'Its Perfectly Normal',
#  'Its So Amazing',
#  'Itty Bitty Kitty Corn',
#  'Jack not jackie',
#  'Jack of hearts',
#  'Jacobs new dress',
#  'Jacobs room to choose',
#  'Jays Gay Agenda',
#  'Jeff Pennant',
#  'Jesus Land',
#  'Julian is a Mermaid',
#  'Juliet Takes a Breath graphic novel',
#  'Juliet Takes a Breath',
#  'Just Help',
#  'King and king',
#  'Kingdom of Ash',
#  'Kissing Kate',
#  'l8r g8r',
#  'Last Night at the Telegraph Club slick sheet',
#  'Last Night at the Telegraph Club',
#  'laura dean keeps breaking up with me',
#  'Lawn Boy',
#  'Layla',
#  "Let's Talk about Race",
#  'Lets Talk About It',
#  'LGBTQ rights',
#  'Lies Knives and Girls in Dresses',
#  'Life is Funny',
#  'light it up',
#  'Like a Hurricane',
#  'Like a Love Story',
#  'Lily and Dunkin',
#  'Little and lion',
#  'Little One',
#  'Little People big dreams Laverne Cox',
#  'Little People Big Dreams RuPaul',
#  'living dead girl',
#  'Living Ink',
#  'Lolita',
#  'Long Way Down',
#  'Looking For Alaska',
#  'Lord of the flies',
#  'Losing Hope slick sheet',
#  'Losing Hope',
#  'Love Lies Beneath',
#  'Love Makes a family',
#  'Love Story Starring My Dead Best Friend',
#  'Love Violet',
#  'Lucky Slick Sheet',
#  'Lucky',
#  'Lullaby slick sheet',
#  'Lullaby',
#  'Luna',
#  'Lunch from home',
#  'Magnolia Flower',
#  'Mama and Mommy and Me in the Middle',
#  'man o war slick sheet',
#  'Man o war',
#  'Marriage of a Thousand Lies',
#  'Marvin Redpost is He a Girl',
#  'Maus 1',
#  'Maus 2',
#  'Max and the Dumb Flower Picture',
#  'Max and the talent show',
#  'Max on the Farm',
#  'maybe not slick sheet',
#  'Maybe Not',
#  'Maybe now',
#  'Maybe Someday',
#  'Me and earl and the dying girl',
#  'Meet Cute',
#  'Meg and Linus',
#  'melissa',
#  'Middle Schools a drag',
#  'Milk and Honey',
#  'Milo Imagines the World',
#  'Miosotis Flores Never Forgets',
#  "Monday's Not Coming",
#  'More Happy Than Not',
#  'My Body is Growing',
#  'my friend dahmer',
#  'My Jim',
#  'My Maddy',
#  'My People',
#  'My Princess Boy',
#  'My Rainbow',
#  'My Shadow is pink',
#  'My Shadow is Purple',
#  'My Sister Daisy',
#  'My Very Own Space',
#  'Native Son',
#  'Neanderthal Opens the Door To The Universe',
#  'Never lore',
#  'Nick and Charlie',
#  'Nineteen Minutes',
#  'Normal People',
#  'Not My Idea A Book About Whiteness',
#  'Not My Problem',
#  'Not Otherwise Specified',
#  'Not that Bad',
#  'Nothing Like You',
#  'November 9 Slick Sheet',
#  'November 9',
#  'On the Bright Side Im Now the Girlfriend of a Sex God',
#  'Once Upon a Tim',
#  'one last stop slick sheet',
#  'One Last Stop',
#  'Opposite Sex',
#  'Optimists Die First',
#  'Oryx and Crake',
#  'Our Skin A First Conversation about Race',
#  'Out of Darkness',
#  'Owl Diaries Get Well Eva',
#  'Papa Daddy and Riley',
#  'Pass It On',
#  'Patricks polka dot tights',
#  'People Kill People',
#  'People of Pride RuPaul Charles',
#  'perfect by Kiri Jorgensen',
#  'Perfect',
#  'Pet',
#  'Pink Blue and You',
#  'Plum',
#  'Point of retreat',
#  'Portnoys Complaint',
#  'Prince and KNight',
#  'protesting police violence in modern america',
#  'pumpkin heads',
#  'Push Slick Sheet',
#  'Push',
#  'Queen of Shadows',
#  'Queer a Graphic History',
#  'Questions and feelings about racism',
#  'Race and Policing in Modern America',
#  'rACIAL jUSTICE IN aMERICA what is the black lives matter movement',
#  'Racial justice in america what is white privilege',
#  'Racial Justice in America',
#  'Ramona Blue',
#  'Rant slick sheet',
#  'Rant',
#  'Ready or not',
#  'Real Live Boyfriends',
#  'Red a crayons story',
#  'Red at the Bone',
#  'Red Hood Slick sheet',
#  'Red Hood',
#  'Red White and Royal Blue',
#  'Redwood and Ponytail',
#  'Relish',
#  'Rethinking Normal',
#  'Rhymes with Witches',
#  'Rick',
#  'Rosie revere engineer',
#  'Rumble',
#  's.e.x second edition',
#  'Sam is my sister',
#  'Scars',
#  'Seeing Gender',
#  'sex an uncensored introduction slick sheet',
#  'SEX an uncensored introduction',
#  'Sex in the Library',
#  'sex is a funny word',
#  'Sex Plus',
#  'she felt like feeling nothing',
#  'Shes my dad',
#  'Shine',
#  'Shiver',
#  'SHOUT',
#  'Silent Mobius Volume 1',
#  'Skin Again',
#  'Skin',
#  'Slammed',
#  'Slaughterhouse Five',
#  'Slavery Wasnt Only in the South',
#  'Smoke',
#  'snuff slicksheet',
#  'Snuff',
#  'Sofia Valdez future prez',
#  'Sold slick sheet',
#  'Sold',
#  'Some Girls Bind',
#  'Some Girls Do',
#  'Speak the Graphic Novel',
#  'Speak',
#  'Spinning',
#  'Splendor',
#  'Stained',
#  'Stamped for kids',
#  'Starla Jean Which Came First the Chicken or the Friendship',
#  'Starting from scratch a wish novel',
#  'Stealing Heaven',
#  'Stitches a memoir',
#  'Story of a Girl',
#  'Strange Truth',
#  'Sully the Raccoon',
#  'Sulwe',
#  'SuperMutant Magic Academy',
#  'TAbitha and Magoo Dress Up Too',
#  'tale of the shadow king',
#  'Teos Tutu',
#  'That is My Dream',
#  'Thats betty',
#  'The 57 Bus',
#  'The 7 Habits of Happy Kids',
#  'The Absolutely True Diary of a Part Time Indian',
#  'The Absolutely True Diary of a Part',
#  'The Art of Drag',
#  'The Art of Racing in the RAin',
#  'The Assassin and the Desert',
#  'The Assassin and the Empire',
#  'The Assassin and the Pirate Lord',
#  'The Assassins Blade',
#  'The bare Naked book',
#  'The Best Laid Plans',
#  'The Black Flamingo',
#  'The Black Friend',
#  'the Bluest Eye',
#  'The Body a guide for occupants',
#  'The Boy and Girl Who Broke the World',
#  'The breakaways',
#  'The Carnival at Bray',
#  'The Color of Earth',
#  'The Complete Idiots Guide to Tantric Sex',
#  'The Day you begin',
#  'The Deep and Dark Blue',
#  'The Duff',
#  'The family book',
#  'The Female of the species',
#  'The Fixer',
#  'The Freedom Writers Diary',
#  'The Gift',
#  'The Girl Who Knew Too Much',
#  'The Glass Menagerie',
#  'The Handmaids Tale The Graphic Novel',
#  'The Handmaids Tale',
#  'The Handsome Girl and Her Beautiful Boy',
#  'The harvey Milk story',
#  'The Hate U Give',
#  'The Haters',
#  'the history of racism in america',
#  'The House on Mango Street',
#  'the House That Wasnt There',
#  'The Infinite Moment of Us',
#  'The invisible life of addie larue',
#  'the Juneteenth Story',
#  'The Kite Runner graphic novel',
#  'The Kite Runner slick sheet',
#  'the Kite Runner',
#  'The Little Black Book for Girlz',
#  'The Love Interest',
#  'The Lovely Bones',
#  'The Many Colors of Harpreet Singh',
#  'The Me I Choose to Be',
#  'The Midnight Lie',
#  'the Moon Within',
#  'The nerdy and the dirty',
#  'The Nowhere Girls',
#  'The One and Only Dylan St Claire',
#  'The Opposite of Innocent',
#  'The pants project',
#  'The Passing Playbook',
#  'The Peacock and the Mermaid',
#  'The Perks of Being a Wallflower',
#  'The Poet X',
#  'The prince and the dressmaker',
#  'The Pronoun Book',
#  'The Rainbow Parade',
#  'The Right Touch',
#  'The Sacrifice of Darkness',
#  'The Sun and her flowers',
#  'The Talk',
#  'the teenage guy',
#  'The Trauma Cleaner slick sheet',
#  'The trauma cleaner',
#  'The Trouble With Chickens',
#  'the truth about alice',
#  'The Undefeated',
#  'the upside of unrequited',
#  'The V Word',
#  'The Violin Makers Daughter',
#  'The Wind Up Bird Chronicle Slick Sheet',
#  'The Wind Up Bird Chronicles',
#  'the Witch Boy',
#  'the Year of the Flood',
#  'The You Ive Never Known',
#  'They Went Left - Copy',
#  'Thirteen reasons why',
#  'This book is antiracist',
#  'This Book is Gay Slick Sheet',
#  'This Book is Gay',
#  'This Book is Not for You',
#  'This is Our Rainbow',
#  'This One Summer',
#  'Throne of Glass',
#  'Thunder Boy Jr',
#  'Tiger Eyes',
#  'Tilt Slick sheet',
#  'Tilt',
#  'To Kill a Mockingbird',
#  'Too Bright to See',
#  'Touch Blue',
#  'Touch',
#  'Tower of Dawn',
#  'Traffick',
#  'Trans plus',
#  'Trans Teen survival Guide',
#  'Triangles',
#  'Tricks Slick Sheet',
#  'Tricks',
#  'TTYL',
#  'turning 15 on the road to freedom',
#  'Twisted',
#  'Two Boys Kissing',
#  'Two More days',
#  'Ugly Love slick sheet',
#  'Ugly Love',
#  'uncomfortable conversations with a black boy',
#  'Unicorns Are the Worst',
#  'Unravel Me',
#  'Verity slick sheet',
#  'Verity',
#  'Wait For You',
#  'Wait What',
#  'Water for Elephants',
#  'Watercress',
#  'Wayward Son',
#  'We are Not Yet Equal',
#  'We Are the Ants',
#  'We rise we resist we raise our voices',
#  'Welcome to st hell',
#  'What About Will',
#  'What are your words',
#  'What Girls are Made of Slick Sheet',
#  'What Girls Are Made Of',
#  'What if Pig',
#  'What My Mother Doesn',
#  'what riley wore',
#  'When Aidan Became a Brother',
#  'When I Grow Up',
#  'When i was the Greatest',
#  'Where I End and You Begin',
#  'Where the crawdads sing',
#  'Who Are You the kids guide to gender identity',
#  'Who has What',
#  'Wicked slick sheet',
#  'Wicked',
#  'Wintergirls',
#  'Without Merit',
#  'woke',
#  'yolk',
#  'YOLO slick sheet',
#  'YOLO',
#  'You a novel',
#  'You be You',
#  'You Matter',
#  'You Too']

# %%
len(pdfs)
# Out:
# 647

# %%
filepath
# Out:
# 'C:\\Users\\c_ull\\data-projects\\scrapy-test\\BookLooks_Reports\\You Too.pdf'

# %%
df.title.value_counts()
# Out:
# ---                          2
# An Ordinary Day              2
# Perfect                      2
# Normal People                1
# Native Son                   1
#                             ..
# Foul is Fair                 1
# Fred Gets Dressed            1
# The Freedom Writers Diary    1
# Friction                     1
# You Too?                     1
# Name: title, Length: 585, dtype: int64

# %%
titles
# Out:
# ['10000 Dresses',
#  '101 Ways to Dance',
#  '33 Snowfish',
#  'A Child Called it',
#  'A Costume for Charly',
#  'A Court of Frost and Starlight Slick Sheet',
#  'A Court of Frost and Starlight',
#  'a court of mist and fury slick sheet',
#  'A Court of Mist and Fury',
#  'A Court of Silver Flames Slick Sheet',
#  'A Court of Silver Flames',
#  'A Court of Thorns and Roses slick sheet',
#  'A Court of Thorns and Roses',
#  'A Court of Wings and Ruin slick sheet',
#  'A Court of Wings and Ruin',
#  'A Day No Pigs Would Die',
#  'A is for activist',
#  'A Kingdom of Flesh and Fire Slick Sheet',
#  'A Kingdom of Flesh and Fire',
#  'A Lesson in Vengeance',
#  'A Quick and easy guide to queer and trans identities',
#  'A Quick and easy guide to they them pronouns',
#  'A Sin Such as this slick sheet',
#  'A Sin Such as This',
#  'A stolen life',
#  'Aaron slater illustrator',
#  'Ablaze With Color',
#  'Ace Voices',
#  'Ada twist scientist',
#  'Adjustment Day slick sheet',
#  'Adjustment day',
#  'Advocate for Yourself',
#  'After',
#  'Al Capone does my shirts',
#  'All American Boys',
#  'All Because You Matter',
#  'All Boys Arent Blue Slick Sheet',
#  'All Boys Arent Blue',
#  'All The Bright Places',
#  'All the Things we do in the dark',
#  'All your perfects slick sheet',
#  'All Your Perfects',
#  'Allegedly',
#  'Alma and How she got her name',
#  'Almost perfect',
#  'Alt Ed',
#  'America',
#  'An Abc of equality',
#  'An Ordinary Day',
#  'Anatomy of a Boyfriend slick sheet',
#  'Anatomy of a Boyfriend',
#  'Anatomy of a single Girl',
#  'And tango makes three',
#  'And They Lived slick sheet',
#  'And they lived',
#  'ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON',
#  'Anne Franks Diary graphic novel',
#  'Antiracist baby',
#  'Antonios card',
#  'Are you a boy or are you a girl',
#  'Are You a Butterfly',
#  'Are you an ant',
#  'Are you my Mother A Comic Drama',
#  'as the crow flies',
#  'Ask the Passengers',
#  'Assassination Classroom Volume 11',
#  'Assassination Classroom Volume 2',
#  'Assassination classroom volume 3',
#  'Assassination Classroom volume 4',
#  'Assassination Classroom Volume 5',
#  'Assassination Classroom volume 6',
#  'Assassination Classroom volume 7',
#  'Assassination Classroom',
#  'Attack of the Black Rectangles',
#  'Autoboyography',
#  'Bad Boy',
#  'Ballet KIds',
#  'Ban this book',
#  'Banned Book Club',
#  'Bathe the cat',
#  'Be Amazing',
#  'Be Prepared',
#  'Be who you are',
#  'Bea by the Sea',
#  'Beautiful Bastard',
#  'Beautiful Disaster slick sheet',
#  'Beautiful Disaster',
#  'Beautiful Slick Sheet',
#  'Beautiful',
#  'Beetle and the Hollow Bones',
#  'Before We Disappear',
#  'Being jazz',
#  'Being You a first conversation about gender',
#  'Beloved',
#  'Beyond Magenta',
#  'Big Wig',
#  'BlackLives Matter',
#  'Blankets',
#  'Blazed',
#  'Blended',
#  'Blue is the Warmest Color',
#  'Bodies are cool',
#  'Body Image',
#  'Bone ghost circles',
#  'Born on the Bayou slick sheet',
#  'Born on the Bayou',
#  'Born Ready',
#  'Boy Girl Boy',
#  'Boy Meets Boy',
#  'Boy Toy',
#  'Boys Dance',
#  'Brave New World',
#  'Brazen',
#  'Breathless slicksheet',
#  'Breathless',
#  'Bright Eyes Brown Skin',
#  'Bumped',
#  'bunnyBear',
#  'Burned',
#  'Bye Bye binary',
#  'Call Me By Your Name Slick Sheet',
#  'Call Me By Your Name',
#  'Call Me Max',
#  'Calvin',
#  'Can I Touch Your Hair',
#  'Cant Take That Away',
#  'Catwoman Soulstealer',
#  'Cemetary Boys',
#  'changing You',
#  'Check Please',
#  'Choke slick sheet',
#  'Choke',
#  'Chosen',
#  'Cinderella is Dead',
#  'Clap when you land',
#  'Class Act',
#  'Clockwork princess',
#  'Closer Slick Sheet',
#  'Closer to Nowhere',
#  'Closer',
#  'Collateral Slick Sheet',
#  'Collateral',
#  'Collected Poms 1947 1980',
#  'Concrete Rose',
#  'Confess',
#  'Cool for the Summer',
#  'crank',
#  'Crown of Midnight',
#  'Cuddly Duddley',
#  'Curls',
#  'Cut',
#  'Daddys Roommate',
#  'Damned slick sheet',
#  'Damned',
#  'Damsel Slick Sheet',
#  'Damsel',
#  'Dead End slick sheet',
#  'Dead End',
#  'Deal with it',
#  'Dear martin',
#  'Dear Sweet Pea',
#  'Death Wind',
#  'Deogratias a Tale of Rwand',
#  'dime',
#  'Discrimination in Society Racial Discrimination',
#  'Doing it',
#  'Doll Bones',
#  'Doomed slick sheet',
#  'Doomed',
#  'Dorothy a different kind of friend',
#  'Dragon Masters Heat of the Lava Dragon',
#  'Drama',
#  'Dream Street',
#  'Dreaming in Cuban',
#  'Dreaming Up',
#  'Dress Codes For Small Towns',
#  'Eleanor and Park',
#  'Embrace Series Book 1',
#  'Emergency Contact',
#  'Empire of Storms Slick Sheet',
#  'Empire of Storms',
#  'Eustace and Clyde',
#  'Everything You EVer Wanted to Know About Puberty',
#  'Everywhere Babies',
#  'Exit here slick sheet',
#  'Exit here',
#  'Extremely Loud and INcredibly Close',
#  'Fable',
#  'Fade',
#  'Fallout',
#  'Fangirl',
#  'Far from Fair',
#  'Felix Ever After',
#  'Feral Sins',
#  'Fight Club',
#  'Finding Cinderella',
#  'Finding Perfect',
#  'Flamer',
#  'Flowers in the attic',
#  'Forbidden',
#  'forever for a year slick sheet',
#  'Forever for a Year',
#  'Forever Slick sheet',
#  'Forever',
#  'Foul is Fair',
#  'Fred Gets Dressed',
#  'Friction',
#  'Friday',
#  'From ARchie to Zack',
#  'From Blood and Ash slick sheet',
#  'From Blood and Ash',
#  'Fun Home',
#  'Gabi A Girl in Pieces',
#  'Gender Queer',
#  'George',
#  'Get a life Chloe Brown',
#  'Ghost boys',
#  'Gilded',
#  'Girl in Translation',
#  'Girls Who Code',
#  'Glass',
#  'Go Ask Alice',
#  'Go Back to Sleep',
#  'Goodnight Racism',
#  'Gossip girl Nobody does it better',
#  'Grandpas camper',
#  'Grit',
#  'Grl2Grl',
#  'Grow up and love your body',
#  'Grown',
#  'Guyaholic',
#  'half a chance',
#  'Half of a Yellow Sun',
#  'haunted slick sheet',
#  'Haunted',
#  'Heartstopper volume 1',
#  'Heartstopper Volume 2',
#  'heartstopper Volume 3',
#  'Heartstopper Volume 4',
#  'Heather Has two Mummies',
#  'Heir of Fire',
#  'Heroine',
#  'Hes my mom',
#  'Him slick sheet',
#  'Him',
#  'Home Body',
#  'Homegoing',
#  'Hooked',
#  'Hoonani Hula Warrior',
#  'Hopeless slick sheet',
#  'Hopeless',
#  'House of Earth and Blood slick sheet',
#  'House of Earth and Blood',
#  'House of Sky and Breath slick sheet',
#  'House of Sky and Breath',
#  'how Beautiful the ordinary',
#  'How it all Blew up',
#  'How to be a young antiracist',
#  'How to Read a Book',
#  'How We Can Live',
#  'I Am Jazz',
#  'I am Margaret Moore',
#  'i am not your perfect mexican daughter',
#  'I Dissent',
#  'I is for immigrants',
#  'I Never',
#  'Identical',
#  'Identity a story of transitioning',
#  'If i was your girl',
#  'If Theres no tomorrow',
#  'If You Come Softly',
#  'Ill Give You the Sun',
#  'Im a Girl',
#  'Im a Unicorn',
#  'Im Basically a Unicorn',
#  'im not a girl',
#  'Impulse',
#  'infandous',
#  'Infinity Son',
#  'invisible monsters remix slick sheet',
#  'Invisible Monsters Remix',
#  'Is This Normal More Girls questions answered by the editors of the care and keeping of you',
#  'Is This NOrmal',
#  'It Ends With Us Slick Sheet',
#  'It Ends With Us',
#  'It feels good to be yourself',
#  'It Isnt rude to be nude',
#  'it starts with us slick sheet',
#  'It starts with Us',
#  'Its Not the Stork',
#  'Its Perfectly Normal 5th edition',
#  'Its Perfectly Normal',
#  'Its So Amazing',
#  'Itty Bitty Kitty Corn',
#  'Jack not jackie',
#  'Jack of hearts',
#  'Jacobs new dress',
#  'Jacobs room to choose',
#  'Jays Gay Agenda',
#  'Jeff Pennant',
#  'Jesus Land',
#  'Julian is a Mermaid',
#  'Juliet Takes a Breath graphic novel',
#  'Juliet Takes a Breath',
#  'Just Help',
#  'King and king',
#  'Kingdom of Ash',
#  'Kissing Kate',
#  'l8r g8r',
#  'Last Night at the Telegraph Club slick sheet',
#  'Last Night at the Telegraph Club',
#  'laura dean keeps breaking up with me',
#  'Lawn Boy',
#  'Layla',
#  "Let's Talk about Race",
#  'Lets Talk About It',
#  'LGBTQ rights',
#  'Lies Knives and Girls in Dresses',
#  'Life is Funny',
#  'light it up',
#  'Like a Hurricane',
#  'Like a Love Story',
#  'Lily and Dunkin',
#  'Little and lion',
#  'Little One',
#  'Little People big dreams Laverne Cox',
#  'Little People Big Dreams RuPaul',
#  'living dead girl',
#  'Living Ink',
#  'Lolita',
#  'Long Way Down',
#  'Looking For Alaska',
#  'Lord of the flies',
#  'Losing Hope slick sheet',
#  'Losing Hope',
#  'Love Lies Beneath',
#  'Love Makes a family',
#  'Love Story Starring My Dead Best Friend',
#  'Love Violet',
#  'Lucky Slick Sheet',
#  'Lucky',
#  'Lullaby slick sheet',
#  'Lullaby',
#  'Luna',
#  'Lunch from home',
#  'Magnolia Flower',
#  'Mama and Mommy and Me in the Middle',
#  'man o war slick sheet',
#  'Man o war',
#  'Marriage of a Thousand Lies',
#  'Marvin Redpost is He a Girl',
#  'Maus 1',
#  'Maus 2',
#  'Max and the Dumb Flower Picture',
#  'Max and the talent show',
#  'Max on the Farm',
#  'maybe not slick sheet',
#  'Maybe Not',
#  'Maybe now',
#  'Maybe Someday',
#  'Me and earl and the dying girl',
#  'Meet Cute',
#  'Meg and Linus',
#  'melissa',
#  'Middle Schools a drag',
#  'Milk and Honey',
#  'Milo Imagines the World',
#  'Miosotis Flores Never Forgets',
#  "Monday's Not Coming",
#  'More Happy Than Not',
#  'My Body is Growing',
#  'my friend dahmer',
#  'My Jim',
#  'My Maddy',
#  'My People',
#  'My Princess Boy',
#  'My Rainbow',
#  'My Shadow is pink',
#  'My Shadow is Purple',
#  'My Sister Daisy',
#  'My Very Own Space',
#  'Native Son',
#  'Neanderthal Opens the Door To The Universe',
#  'Never lore',
#  'Nick and Charlie',
#  'Nineteen Minutes',
#  'Normal People',
#  'Not My Idea A Book About Whiteness',
#  'Not My Problem',
#  'Not Otherwise Specified',
#  'Not that Bad',
#  'Nothing Like You',
#  'November 9 Slick Sheet',
#  'November 9',
#  'On the Bright Side Im Now the Girlfriend of a Sex God',
#  'Once Upon a Tim',
#  'one last stop slick sheet',
#  'One Last Stop',
#  'Opposite Sex',
#  'Optimists Die First',
#  'Oryx and Crake',
#  'Our Skin A First Conversation about Race',
#  'Out of Darkness',
#  'Owl Diaries Get Well Eva',
#  'Papa Daddy and Riley',
#  'Pass It On',
#  'Patricks polka dot tights',
#  'People Kill People',
#  'People of Pride RuPaul Charles',
#  'perfect by Kiri Jorgensen',
#  'Perfect',
#  'Pet',
#  'Pink Blue and You',
#  'Plum',
#  'Point of retreat',
#  'Portnoys Complaint',
#  'Prince and KNight',
#  'protesting police violence in modern america',
#  'pumpkin heads',
#  'Push Slick Sheet',
#  'Push',
#  'Queen of Shadows',
#  'Queer a Graphic History',
#  'Questions and feelings about racism',
#  'Race and Policing in Modern America',
#  'rACIAL jUSTICE IN aMERICA what is the black lives matter movement',
#  'Racial justice in america what is white privilege',
#  'Racial Justice in America',
#  'Ramona Blue',
#  'Rant slick sheet',
#  'Rant',
#  'Ready or not',
#  'Real Live Boyfriends',
#  'Red a crayons story',
#  'Red at the Bone',
#  'Red Hood Slick sheet',
#  'Red Hood',
#  'Red White and Royal Blue',
#  'Redwood and Ponytail',
#  'Relish',
#  'Rethinking Normal',
#  'Rhymes with Witches',
#  'Rick',
#  'Rosie revere engineer',
#  'Rumble',
#  's.e.x second edition',
#  'Sam is my sister',
#  'Scars',
#  'Seeing Gender',
#  'sex an uncensored introduction slick sheet',
#  'SEX an uncensored introduction',
#  'Sex in the Library',
#  'sex is a funny word',
#  'Sex Plus',
#  'she felt like feeling nothing',
#  'Shes my dad',
#  'Shine',
#  'Shiver',
#  'SHOUT',
#  'Silent Mobius Volume 1',
#  'Skin Again',
#  'Skin',
#  'Slammed',
#  'Slaughterhouse Five',
#  'Slavery Wasnt Only in the South',
#  'Smoke',
#  'snuff slicksheet',
#  'Snuff',
#  'Sofia Valdez future prez',
#  'Sold slick sheet',
#  'Sold',
#  'Some Girls Bind',
#  'Some Girls Do',
#  'Speak the Graphic Novel',
#  'Speak',
#  'Spinning',
#  'Splendor',
#  'Stained',
#  'Stamped for kids',
#  'Starla Jean Which Came First the Chicken or the Friendship',
#  'Starting from scratch a wish novel',
#  'Stealing Heaven',
#  'Stitches a memoir',
#  'Story of a Girl',
#  'Strange Truth',
#  'Sully the Raccoon',
#  'Sulwe',
#  'SuperMutant Magic Academy',
#  'TAbitha and Magoo Dress Up Too',
#  'tale of the shadow king',
#  'Teos Tutu',
#  'That is My Dream',
#  'Thats betty',
#  'The 57 Bus',
#  'The 7 Habits of Happy Kids',
#  'The Absolutely True Diary of a Part Time Indian',
#  'The Absolutely True Diary of a Part',
#  'The Art of Drag',
#  'The Art of Racing in the RAin',
#  'The Assassin and the Desert',
#  'The Assassin and the Empire',
#  'The Assassin and the Pirate Lord',
#  'The Assassins Blade',
#  'The bare Naked book',
#  'The Best Laid Plans',
#  'The Black Flamingo',
#  'The Black Friend',
#  'the Bluest Eye',
#  'The Body a guide for occupants',
#  'The Boy and Girl Who Broke the World',
#  'The breakaways',
#  'The Carnival at Bray',
#  'The Color of Earth',
#  'The Complete Idiots Guide to Tantric Sex',
#  'The Day you begin',
#  'The Deep and Dark Blue',
#  'The Duff',
#  'The family book',
#  'The Female of the species',
#  'The Fixer',
#  'The Freedom Writers Diary',
#  'The Gift',
#  'The Girl Who Knew Too Much',
#  'The Glass Menagerie',
#  'The Handmaids Tale The Graphic Novel',
#  'The Handmaids Tale',
#  'The Handsome Girl and Her Beautiful Boy',
#  'The harvey Milk story',
#  'The Hate U Give',
#  'The Haters',
#  'the history of racism in america',
#  'The House on Mango Street',
#  'the House That Wasnt There',
#  'The Infinite Moment of Us',
#  'The invisible life of addie larue',
#  'the Juneteenth Story',
#  'The Kite Runner graphic novel',
#  'The Kite Runner slick sheet',
#  'the Kite Runner',
#  'The Little Black Book for Girlz',
#  'The Love Interest',
#  'The Lovely Bones',
#  'The Many Colors of Harpreet Singh',
#  'The Me I Choose to Be',
#  'The Midnight Lie',
#  'the Moon Within',
#  'The nerdy and the dirty',
#  'The Nowhere Girls',
#  'The One and Only Dylan St Claire',
#  'The Opposite of Innocent',
#  'The pants project',
#  'The Passing Playbook',
#  'The Peacock and the Mermaid',
#  'The Perks of Being a Wallflower',
#  'The Poet X',
#  'The prince and the dressmaker',
#  'The Pronoun Book',
#  'The Rainbow Parade',
#  'The Right Touch',
#  'The Sacrifice of Darkness',
#  'The Sun and her flowers',
#  'The Talk',
#  'the teenage guy',
#  'The Trauma Cleaner slick sheet',
#  'The trauma cleaner',
#  'The Trouble With Chickens',
#  'the truth about alice',
#  'The Undefeated',
#  'the upside of unrequited',
#  'The V Word',
#  'The Violin Makers Daughter',
#  'The Wind Up Bird Chronicle Slick Sheet',
#  'The Wind Up Bird Chronicles',
#  'the Witch Boy',
#  'the Year of the Flood',
#  'The You Ive Never Known',
#  'They Went Left - Copy',
#  'Thirteen reasons why',
#  'This book is antiracist',
#  'This Book is Gay Slick Sheet',
#  'This Book is Gay',
#  'This Book is Not for You',
#  'This is Our Rainbow',
#  'This One Summer',
#  'Throne of Glass',
#  'Thunder Boy Jr',
#  'Tiger Eyes',
#  'Tilt Slick sheet',
#  'Tilt',
#  'To Kill a Mockingbird',
#  'Too Bright to See',
#  'Touch Blue',
#  'Touch',
#  'Tower of Dawn',
#  'Traffick',
#  'Trans plus',
#  'Trans Teen survival Guide',
#  'Triangles',
#  'Tricks Slick Sheet',
#  'Tricks',
#  'TTYL',
#  'turning 15 on the road to freedom',
#  'Twisted',
#  'Two Boys Kissing',
#  'Two More days',
#  'Ugly Love slick sheet',
#  'Ugly Love',
#  'uncomfortable conversations with a black boy',
#  'Unicorns Are the Worst',
#  'Unravel Me',
#  'Verity slick sheet',
#  'Verity',
#  'Wait For You',
#  'Wait What',
#  'Water for Elephants',
#  'Watercress',
#  'Wayward Son',
#  'We are Not Yet Equal',
#  'We Are the Ants',
#  'We rise we resist we raise our voices',
#  'Welcome to st hell',
#  'What About Will',
#  'What are your words',
#  'What Girls are Made of Slick Sheet',
#  'What Girls Are Made Of',
#  'What if Pig',
#  'What My Mother Doesn',
#  'what riley wore',
#  'When Aidan Became a Brother',
#  'When I Grow Up',
#  'When i was the Greatest',
#  'Where I End and You Begin',
#  'Where the crawdads sing',
#  'Who Are You the kids guide to gender identity',
#  'Who has What',
#  'Wicked slick sheet',
#  'Wicked',
#  'Wintergirls',
#  'Without Merit',
#  'woke',
#  'yolk',
#  'YOLO slick sheet',
#  'YOLO',
#  'You a novel',
#  'You be You',
#  'You Matter',
#  'You Too']

# %%
badPDF = 'http://booklooks.org/data/files/Book Looks Reports/Allegedly.pdf'
pdf_links=[]
for i in range(len(links):
    url = links[i]
    r = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(r.content,'html')
    for line in soup.find_all('a')[35:-2]:
        pdf_links.append(path+line.get('href'))
        pdf_links = list(set(pdf_links))
    if badPDF in pdf_links:
        pdf_links.remove(badPDF)

pdf_path = 'BookLooks_reports/'
if os.path.exists(pdf_path)==False:
    os.mkdir(pdf_path)
filepath = pdf_path+url.split("/")[-2]
if os.path.exists(filepath)==False:
    os.mkdir(filepath)    
for i in range(len(pdf_links)):
    url = pdf_links[i]
    filepath = pdf_path+url.split("/")[-2]
    if os.path.exists(filepath)==False:
        os.mkdir(filepath) 
    r = requests.get(url=url, headers=headers)
    url.split('/')[-1]
    os.chdir(filepath)
    with open(str(url.split('/')[-1]), 'wb') as f:
        f.write(r.content)

# %%
badPDF = 'http://booklooks.org/data/files/Book Looks Reports/Allegedly.pdf'
pdf_links=[]
pdf_path = 'BookLooks_reports/'
if os.path.exists(pdf_path)==False:
    os.mkdir(pdf_path)
for i in range(len(links)):
    url = links[i]
    r = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(r.content,'html')
    for line in soup.find_all('a')[35:-2]:
        pdf_links.append(path+line.get('href'))
        pdf_links = list(set(pdf_links))
if badPDF in pdf_links:
    pdf_links.remove(badPDF)
for i in range(len(pdf_links[:-1])):
    url = pdf_links[i]
    filepath = pdf_path+url.split("/")[-2]
    if os.path.exists(filepath)==False:
        os.mkdir(filepath) 
    r = requests.get(url=url, headers=headers)
    print(r.content())
os.chdir('..')

# %%
pdf_links[:-1]
# Out:
# ['http://booklooks.org/data/files/Book Looks Reports/A/A is for activist.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Aaron slater illustrator.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Ablaze With Color.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Ace Voices.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Ada twist scientist.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Adjustment Day slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Adjustment day.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Advocate for Yourself.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/After.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Al Capone does my shirts.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All American Boys.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All Because You Matter.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All Boys Arent Blue Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All Boys Arent Blue.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All The Bright Places.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All Your Perfects.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All the Things we do in the dark.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/All your perfects slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Allegedly.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Alma and How she got her name.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Almost perfect.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Alt Ed.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/America.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/An Abc of equality.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/An Ordinary Day.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a Boyfriend slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a Boyfriend.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a single Girl.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/And They Lived slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/And tango makes three.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/And they lived.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Anne Franks Diary graphic novel.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Antiracist baby.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Antonios card.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Are You a Butterfly.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Are you a boy or are you a girl.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Are you an ant.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Ask the Passengers.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 11.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 2.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 5.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 4.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 6.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 7.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Assassination classroom volume 3.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Attack of the Black Rectangles.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/Autoboyography.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Absolutely True Diary of a Part.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Art of Drag.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Art of Racing in the RAin.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Assassin and the Desert.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Assassin and the Empire.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Assassin and the Pirate Lord.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/The Assassins Blade.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/A/as the crow flies.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bad Boy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Ballet KIds.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Ban this book.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Banned Book Club.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bathe the cat.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Be Amazing.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Be Prepared.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Be who you are.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bea by the Sea.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beautiful Bastard.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beautiful Disaster slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beautiful Disaster.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beautiful Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beautiful.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beetle and the Hollow Bones.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Before We Disappear.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Being You a first conversation about gender.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Being jazz.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beloved.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Beyond Magenta.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Big Wig.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/BlackLives Matter.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Blankets.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Blazed.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Blended.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Blue is the Warmest Color.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bodies are cool.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Body Image.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bone ghost circles.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Born Ready.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Born on the Bayou slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Born on the Bayou.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Boy Girl Boy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Boy Meets Boy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Boy Toy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Boys Dance.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Brave New World.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Brazen.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Breathless slicksheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Breathless.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bright Eyes Brown Skin.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bumped.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Burned.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/Bye Bye binary.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The Best Laid Plans.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The Black Flamingo.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The Black Friend.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The Body a guide for occupants.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The Boy and Girl Who Broke the World.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The bare Naked book.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/The breakaways.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/bunnyBear.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/B/the Bluest Eye.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Child Called it.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Costume for Charly.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Frost and Starlight Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Frost and Starlight slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Frost and Starlight.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Mist and Fury.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Silver Flames Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Silver Flames.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Thorns and Roses slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Thorns and Roses.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Wings and Ruin slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/A Court of Wings and Ruin.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Call Me By Your Name Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Call Me By Your Name.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Call Me Max.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Calvin.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Can I Touch Your Hair.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Cant Take That Away.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Catwoman Soulstealer.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Cemetary Boys.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Check Please.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Choke slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Choke.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Chosen.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Cinderella is Dead.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Clap when you land.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Class Act.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Clockwork princess.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Closer Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/Closer to Nowhere.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/C/
pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/U/the upside of unrequited.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/U/uncomfortable conversations with a black boy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/V/The V Word.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/V/The Violin Makers Daughter.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/V/Verity slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/V/Verity.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/The Wind Up Bird Chronicle Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/The Wind Up Bird Chronicles.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wait For You.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wait What.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Water for Elephants.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Watercress.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wayward Son.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/We Are the Ants.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/We are Not Yet Equal.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/We rise we resist we raise our voices.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Welcome to st hell.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What About Will.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What Girls Are Made Of.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What Girls are Made of Slick Sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What My Mother Doesn.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What are your words.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/What if Pig.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/When Aidan Became a Brother.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/When I Grow Up.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/When i was the Greatest.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Where I End and You Begin.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Where the crawdads sing.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Who Are You the kids guide to gender identity.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Who has What.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wicked slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wicked.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Wintergirls.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/Without Merit.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/the Witch Boy.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/what riley wore.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/W/woke.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/The You Ive Never Known.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/YOLO slick sheet.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/YOLO.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/You Matter.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/You Too.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/You a novel.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/You be You.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/the Year of the Flood.pdf',
#  'http://booklooks.org/data/files/Book Looks Reports/Y/yolk.pdf']

# %%
for i in range(len(pdf_links[:-1])):
    url = pdf_links[i]
    filepath = pdf_path+url.split("/")[-2]
    if os.path.exists(filepath)==False:
        os.mkdir(filepath) 
    r = requests.get(url=url, headers=headers)
    print(r.content())
#     url.split('/')[-1]
#     os.chdir(filepath)
#     with open(str(url.split('/')[-1]), 'wb') as f:
#         f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
#       5     os.mkdir(filepath)
#       6 r = requests.get(url=url, headers=headers)
# ----> 7 print(r.content())
#
# TypeError: 'bytes' object is not callable

# %%
os.getcwd()
# Out:
# 'C:\\Users\\c_ull\\data-projects\\scrapy-test'

# %%
os.chdir('..')

# %%
for i in range(len(pdf_links[:-1])):
    url = pdf_links[i]
    filepath = pdf_path+url.split('/')[-2]+"/" 
    r = requests.get(url= url, headers=headers)
    if not os.path.exists(filepath):
        os.makedirs(filepath)
    else:
        print("file path "+filepath+" exists.")
        print(url)
        
#         with open(str(url.split('/')[-1]), 'wb') as f:
#             f.write(r.content)
#     os.chdir(pdf_path)
#     print("file path "+filepath+" exists.")
# Out:
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/A is for activist.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Aaron slater illustrator.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Ablaze With Color.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Ace Voices.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Ada twist scientist.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Adjustment Day slick sheet.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Adjustment day.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Advocate for Yourself.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/After.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Al Capone does my shirts.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All American Boys.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All Because You Matter.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All Boys Arent Blue Slick Sheet.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All Boys Arent Blue.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All The Bright Places.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All Your Perfects.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All the Things we do in the dark.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/All your perfects slick sheet.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Allegedly.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Alma and How she got her name.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Almost perfect.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Alt Ed.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/America.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/An Abc of equality.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/An Ordinary Day.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a Boyfriend slick sheet.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a Boyfriend.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Anatomy of a single Girl.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/And They Lived slick sheet.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/And tango makes three.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/And they lived.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Anne Franks Diary graphic novel.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Antiracist baby.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Antonios card.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Are You a Butterfly.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Are you a boy or are you a girl.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Are you an ant.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Ask the Passengers.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 11.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 2.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom Volume 5.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 4.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 6.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom volume 7.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination Classroom.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Assassination classroom volume 3.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Attack of the Black Rectangles.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/Autoboyography.pdf
# file path BookLooks_reports/A/ exists.
# http://booklooks.org/data/files/Book Looks Reports/A/The
pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Speak the Graphic Novel.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Speak.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Spinning.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Splendor.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Stained.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Stamped for kids.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Starla Jean Which Came First the Chicken or the Friendship.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Starting from scratch a wish novel.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Stealing Heaven.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Stitches a memoir.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Story of a Girl.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Strange Truth.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Sully the Raccoon.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/Sulwe.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/SuperMutant Magic Academy.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/The Sacrifice of Darkness.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/The Sun and her flowers.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/s.e.x second edition.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/sex an uncensored introduction slick sheet.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/sex is a funny word.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/she felt like feeling nothing.pdf
# file path BookLooks_reports/S/ exists.
# http://booklooks.org/data/files/Book Looks Reports/S/snuff slicksheet.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/TTYL.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Teos Tutu.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/That is My Dream.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Thats betty.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/The Talk.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/The Trauma Cleaner slick sheet.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/The Trouble With Chickens.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/The trauma cleaner.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/They Went Left - Copy.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Thirteen reasons why.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This Book is Gay Slick Sheet.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This Book is Gay.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This Book is Not for You.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This One Summer.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This book is antiracist.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/This is Our Rainbow.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Throne of Glass.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Thunder Boy Jr.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tiger Eyes.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tilt Slick sheet.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tilt.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/To Kill a Mockingbird.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Too Bright to See.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Touch Blue.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Touch.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tower of Dawn.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Traffick.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Trans Teen survival Guide.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Trans plus.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Triangles.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tricks Slick Sheet.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Tricks.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Twisted.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Two Boys Kissing.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/Two More days.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/the teenage guy.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/the truth about alice.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/this Book is Gay.pdf
# file path BookLooks_reports/T/ exists.
# http://booklooks.org/data/files/Book Looks Reports/T/turning 15 on the road to freedom.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/Ugly Love slick sheet.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/Ugly Love.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/Unicorns Are the Worst.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/Unravel Me.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/the upside of unrequited.pdf
# file path BookLooks_reports/U/ exists.
# http://booklooks.org/data/files/Book Looks Reports/U/uncomfortable conversations with a black boy.pdf
# file path BookLooks_reports/V/ exists.
# http://booklooks.org/data/files/Book Looks Reports/V/The Violin Makers Daughter.pdf
# file path BookLooks_reports/V/ exists.
# http://booklooks.org/data/files/Book Looks Reports/V/Verity slick sheet.pdf
# file path BookLooks_reports/V/ exists.
# http://booklooks.org/data/files/Book Looks Reports/V/Verity.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/The Wind Up Bird Chronicles.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wait For You.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wait What.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Water for Elephants.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Watercress.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wayward Son.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/We Are the Ants.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/We are Not Yet Equal.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/We rise we resist we raise our voices.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Welcome to st hell.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What About Will.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What Girls Are Made Of.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What Girls are Made of Slick Sheet.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What My Mother Doesn.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What are your words.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/What if Pig.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/When Aidan Became a Brother.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/When I Grow Up.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/When i was the Greatest.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Where I End and You Begin.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Where the crawdads sing.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Who Are You the kids guide to gender identity.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Who has What.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wicked slick sheet.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wicked.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Wintergirls.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/Without Merit.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/the Witch Boy.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/what riley wore.pdf
# file path BookLooks_reports/W/ exists.
# http://booklooks.org/data/files/Book Looks Reports/W/woke.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/YOLO slick sheet.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/YOLO.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/You Matter.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/You Too.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/You a novel.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/You be You.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/the Year of the Flood.pdf
# file path BookLooks_reports/Y/ exists.
# http://booklooks.org/data/files/Book Looks Reports/Y/yolk.pdf

# %%
for i in range(len(pdf_links[:-1])):
    url = pdf_links[i]
    #filepath = pdf_path+url.split('/')[-2]+"/" 
    r = requests.get(url= url, headers=headers)
    with open(str(url.split('/')[-1]), 'wb') as f:
        f.write(r.content)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\c_ull\\data-projects\\scrapy-test\\BookLooks_reports'

# %%
os.chdir(pdf_path)

# %%
pdf_path
# Out:
# 'BookLooks_reports/'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\c_ull\\data-projects\\scrapy-test\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\BookLooks_reports\\A'

# %%
os.chdir("BookLooks_reports/")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\c_ull\\data-projects\\scrapy-test\\BookLooks_reports'

# %%
url = pdf_links[1]
r = requests.get(url=url, headers=headers)
url.split('/')[-1]
with open(str(url.split('/')[-1]), 'wb') as f:
    f.write(r.content)
# Out:
# 'http://booklooks.org/data/files/Book Looks Reports/B/Bright Eyes Brown Skin.pdf'

# %%
url.split('/')[-1]
with open(str(url.split('/')[-1]), 'wb') as f:
    f.write(r.content)
# Out:
# 'Bright Eyes Brown Skin.pdf'

# %%
with open(str(url.split('/')[-1]), 'wb') as f:
    f.write(r.content)

# %%
BeautifulSoup(r.content,'html')
# Out:
# <html><body><p>%PDF-1.7
# %µµµµ
# 1 0 obj
# &lt;&gt;/OutputIntents[&lt;&gt;] /Metadata 157 0 R/ViewerPreferences 158 0 R&gt;&gt;
# endobj
# 2 0 obj
# &lt;&gt;
# endobj
# 3 0 obj
# &lt;&gt;/ExtGState&lt;&gt;/XObject&lt;&gt;/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] &gt;&gt;/MediaBox[ 0 0 612 792] /Contents 4 0 R/Group&lt;&gt;/StructParents 0&gt;&gt;
# endobj
# 4 0 obj
# &lt;</p></body></html>

# %%
reader = PdfReader(url)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 reader = PdfReader(url)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_reader.py:317, in PdfReader.__init__(self, stream, strict, password)
#     311     logger_warning(
#     312         "PdfReader stream/file object is not in binary mode. "
#     313         "It may not be read correctly.",
#     314         __name__,
#     315     )
#     316 if isinstance(stream, (str, Path)):
# --> 317     with open(stream, "rb") as fh:
#     318         stream = BytesIO(fh.read())
#     319 self.read(stream)
#
# OSError: [Errno 22] Invalid argument: 'http://booklooks.org/data/files/Book Looks Reports/A/A is for activist.pdf'

# %%
df1=pd.DataFrame(columns=['title', 'author', 'rating', 'slick_sheet'])

# %%
df1=pd.concat([df1,df])

# %%
pdf_path = 'BookLooks_reports/'

# %%
pdf_path = 'BookLooks_reports/'
if os.path.exists(pdf_path)==False:
    os.mkdir(pdf_path)
filepath = pdf_path+url.split("/")[-2]
if os.path.exists(filepath)==False:
    os.mkdir(filepath)

# %%
filepath = pdf_path+url.split("/")[-2]
if os.path.exists(filepath)==False:
    os.mkdir(filepath)
# Out:
# 'B'

# %%
pdf_path+url.split("/")[-2]
# Out:
# 'BookLooks_reports/B'

# %%
url.split()
# Out:
# 'http://booklooks.org/data/files/Book Looks Reports/B/Bright Eyes Brown Skin.pdf'
